# %%
import tkinter as tk
from tkinter import messagebox

# Kitap verilerini saklamak için bir liste
kutuphane = []

# Kitap ekleme fonksiyonu
def kitap_ekle():
    kitap_adi = kitap_adi_entry.get()
    yazar_adi = yazar_adi_entry.get()
    
    if kitap_adi and yazar_adi:
        kutuphane.append({"isim": kitap_adi, "yazar": yazar_adi})
        kitap_listesi.insert(tk.END, f"{kitap_adi} - {yazar_adi}")
        kitap_adi_entry.delete(0, tk.END)
        yazar_adi_entry.delete(0, tk.END)
        messagebox.showinfo("Başarılı", "Kitap eklendi!")
    else:
        messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")

# Kitap arama fonksiyonu
def kitap_ara():
    arama_kelimesi = arama_entry.get()
    sonuc_listesi.delete(0, tk.END)
    bulunan_kitaplar = [kitap for kitap in kutuphane if arama_kelimesi.lower() in kitap["isim"].lower() or arama_kelimesi.lower() in kitap["yazar"].lower()]
    
    if bulunan_kitaplar:
        for kitap in bulunan_kitaplar:
            sonuc_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")
    else:
        messagebox.showinfo("Sonuç Yok", "Aradığınız kitap bulunamadı.")
    
# Tkinter ana penceresi
pencere = tk.Tk()
pencere.title("Kütüphane Uygulaması")

# Kitap Ekleme Alanı
kitap_adi_label = tk.Label(pencere, text="Kitap Adı")
kitap_adi_label.pack()

kitap_adi_entry = tk.Entry(pencere)
kitap_adi_entry.pack()

yazar_adi_label = tk.Label(pencere, text="Yazar Adı")
yazar_adi_label.pack()

yazar_adi_entry = tk.Entry(pencere)
yazar_adi_entry.pack()

kitap_ekle_buton = tk.Button(pencere, text="Kitap Ekle", command=kitap_ekle)
kitap_ekle_buton.pack()

# Kitap silme fonksiyonu
def kitap_sil():
    secilen_kitap = kitap_listesi.curselection()
    if secilen_kitap:
        kitap_listesi.delete(secilen_kitap)
        del kutuphane[secilen_kitap[0]]
        messagebox.showinfo("Başarılı", "Kitap silindi!")
    else:
        messagebox.showwarning("Hata", "Lütfen silmek için bir kitap seçin!")

# Kitap Silme Butonu
kitap_sil_buton = tk.Button(pencere, text="Kitap Sil", command=kitap_sil)
kitap_sil_buton.pack()


# Kitap Listesi
kitap_listesi_label = tk.Label(pencere, text="Kitap Listesi")
kitap_listesi_label.pack()

kitap_listesi = tk.Listbox(pencere)
kitap_listesi.pack()

# Kitap Arama Alanı
arama_label = tk.Label(pencere, text="Kitap Ara")
arama_label.pack()

arama_entry = tk.Entry(pencere)
arama_entry.pack()

arama_buton = tk.Button(pencere, text="Ara", command=kitap_ara)
arama_buton.pack()

# Arama Sonuçları
sonuc_listesi_label = tk.Label(pencere, text="Arama Sonuçları")
sonuc_listesi_label.pack()

sonuc_listesi = tk.Listbox(pencere)
sonuc_listesi.pack()

# Ana döngü
pencere.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import ttk  # Modern görünümler için ttk kullanımı

# Kitap verilerini saklamak için bir liste
kutuphane = []

# Kitap ekleme fonksiyonu
def kitap_ekle():
    kitap_adi = kitap_adi_entry.get()
    yazar_adi = yazar_adi_entry.get()
    
    if kitap_adi and yazar_adi:
        kutuphane.append({"isim": kitap_adi, "yazar": yazar_adi})
        kitap_listesi.insert(tk.END, f"{kitap_adi} - {yazar_adi}")
        kitap_adi_entry.delete(0, tk.END)
        yazar_adi_entry.delete(0, tk.END)
        messagebox.showinfo("Başarılı", "Kitap eklendi!")
    else:
        messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")

# Kitap arama fonksiyonu
def kitap_ara():
    arama_kelimesi = arama_entry.get()
    sonuc_listesi.delete(0, tk.END)
    bulunan_kitaplar = [kitap for kitap in kutuphane if arama_kelimesi.lower() in kitap["isim"].lower() or arama_kelimesi.lower() in kitap["yazar"].lower()]
    
    if bulunan_kitaplar:
        for kitap in bulunan_kitaplar:
            sonuc_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")
    else:
        messagebox.showinfo("Sonuç Yok", "Aradığınız kitap bulunamadı.")

# Tkinter ana penceresi
pencere = tk.Tk()
pencere.title("Kütüphane Uygulaması")
pencere.geometry("500x600")
pencere.configure(bg="#e1f5fe")  # Arkaplan rengi (açık mavi)

# Başlık
baslik_label = tk.Label(pencere, text="📚 Kütüphane Uygulaması", font=("Helvetica", 16, "bold"), bg="#e1f5fe", fg="#0277bd")
baslik_label.pack(pady=10)

# Kitap Ekleme Alanı
frame_kitap_ekle = tk.Frame(pencere, bg="#e1f5fe")
frame_kitap_ekle.pack(pady=10)

kitap_adi_label = tk.Label(frame_kitap_ekle, text="Kitap Adı:", bg="#e1f5fe", fg="#01579b", font=("Arial", 12))
kitap_adi_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

kitap_adi_entry = tk.Entry(frame_kitap_ekle, font=("Arial", 12), width=30)
kitap_adi_entry.grid(row=0, column=1, padx=5, pady=5)

yazar_adi_label = tk.Label(frame_kitap_ekle, text="Yazar Adı:", bg="#e1f5fe", fg="#01579b", font=("Arial", 12))
yazar_adi_label.grid(row=1, column=0, padx=5, pady=5, sticky="w")

yazar_adi_entry = tk.Entry(frame_kitap_ekle, font=("Arial", 12), width=30)
yazar_adi_entry.grid(row=1, column=1, padx=5, pady=5)

kitap_ekle_buton = tk.Button(frame_kitap_ekle, text="Kitap Ekle", font=("Arial", 12, "bold"), bg="#4caf50", fg="white", command=kitap_ekle)
kitap_ekle_buton.grid(row=2, column=0, columnspan=2, pady=10)

# Kitap Listesi
kitap_listesi_label = tk.Label(pencere, text="📖 Kitap Listesi", bg="#e1f5fe", fg="#0277bd", font=("Helvetica", 14, "bold"))
kitap_listesi_label.pack()

kitap_listesi = tk.Listbox(pencere, font=("Arial", 12), width=50, height=10, bg="#ffffff", fg="#000000", selectbackground="#bbdefb")
kitap_listesi.pack(pady=10)

# Kitap Arama Alanı
frame_arama = tk.Frame(pencere, bg="#e1f5fe")
frame_arama.pack(pady=10)

arama_label = tk.Label(frame_arama, text="Ara:", bg="#e1f5fe", fg="#01579b", font=("Arial", 12))
arama_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

arama_entry = tk.Entry(frame_arama, font=("Arial", 12), width=30)
arama_entry.grid(row=0, column=1, padx=5, pady=5)

arama_buton = tk.Button(frame_arama, text="Ara", font=("Arial", 12, "bold"), bg="#0288d1", fg="white", command=kitap_ara)
arama_buton.grid(row=0, column=2, padx=5, pady=5)

# Arama Sonuçları
sonuc_listesi_label = tk.Label(pencere, text="🔍 Arama Sonuçları", bg="#e1f5fe", fg="#0277bd", font=("Helvetica", 14, "bold"))
sonuc_listesi_label.pack()

sonuc_listesi = tk.Listbox(pencere, font=("Arial", 12), width=50, height=5, bg="#ffffff", fg="#000000", selectbackground="#bbdefb")
sonuc_listesi.pack(pady=10)

# Ana döngü
pencere.mainloop()

# %%
# Kitap seçildiğinde açıklamayı gösteren pencere
def kitap_aciklama_goster(event):
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        kitap_adi = kitap_listesi.get(secili_kitap)
        kitap_bilgisi = next((k for k in kutuphane if f"{k['isim']} - {k['yazar']}" == kitap_adi), None)
        if kitap_bilgisi:
            # Yeni bir pencere oluştur
            detay_pencere = tk.Toplevel(pencere)
            detay_pencere.title("Kitap Detayları")
            detay_pencere.geometry("400x300")

            # Kitap detaylarını göster
            tk.Label(detay_pencere, text=f"Kitap Adı: {kitap_bilgisi['isim']}", font=("Arial", 12, "bold")).pack(pady=5)
            tk.Label(detay_pencere, text=f"Yazar Adı: {kitap_bilgisi['yazar']}", font=("Arial", 12, "bold")).pack(pady=5)
            tk.Label(detay_pencere, text="Açıklama:", font=("Arial", 12, "bold")).pack(pady=5)

            # Text widget oluştur ve açıklamayı ekle
            aciklama_text = tk.Text(detay_pencere, height=10, width=40, wrap=tk.WORD)
            aciklama_text.insert(tk.END, kitap_bilgisi.get("aciklama", "Açıklama yok."))
            aciklama_text.pack()

# %%
import tkinter as tk
from tkinter import messagebox
import json

# Dosyadan kitapları okuma
def kitaplari_yukle():
    try:
        with open("kitaplar.json", "r", encoding="utf-8") as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        return []

# Dosyaya kitapları kaydetme
def kitaplari_kaydet():
    with open("kitaplar.json", "w", encoding="utf-8") as f:
        json.dump(kutuphane, f, ensure_ascii=False, indent=4)

# Kitap ekleme fonksiyonu
def kitap_ekle():
    kitap_adi = kitap_adi_entry.get()
    yazar_adi = yazar_adi_entry.get()
    
    if kitap_adi and yazar_adi:
        kutuphane.append({"isim": kitap_adi, "yazar": yazar_adi})
        kitap_listesi.insert(tk.END, f"{kitap_adi} - {yazar_adi}")
        kitap_adi_entry.delete(0, tk.END)
        yazar_adi_entry.delete(0, tk.END)
        kitaplari_kaydet()  # Yeni kitabı dosyaya kaydet
        messagebox.showinfo("Başarılı", "Kitap eklendi!")
    else:
        messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")

# Kitap silme fonksiyonu
def kitap_sil():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        kitap_adi = kitap_listesi.get(secili_kitap)
        kitap_listesi.delete(secili_kitap)
        kutuphane.remove({"isim": kitap_adi.split(" - ")[0], "yazar": kitap_adi.split(" - ")[1]})
        kitaplari_kaydet()  # Kitap silindiğinde dosyayı güncelle
        messagebox.showinfo("Başarılı", f"{kitap_adi} silindi!")
    else:
        messagebox.showwarning("Hata", "Lütfen silmek istediğiniz kitabı seçin.")

# Kitap düzenleme fonksiyonu
def kitap_duzenle():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        eski_kitap = kitap_listesi.get(secili_kitap)
        eski_isim, eski_yazar = eski_kitap.split(" - ")
        
        # Kullanıcıdan yeni bilgiler
        yeni_isim = kitap_adi_entry.get()
        yeni_yazar = yazar_adi_entry.get()
        
        if yeni_isim and yeni_yazar:
            kutuphane.remove({"isim": eski_isim, "yazar": eski_yazar})
            kutuphane.append({"isim": yeni_isim, "yazar": yeni_yazar})
            kitap_listesi.delete(secili_kitap)
            kitap_listesi.insert(secili_kitap, f"{yeni_isim} - {yeni_yazar}")
            kitaplari_kaydet()  # Güncellenen bilgiyi dosyaya kaydet
            messagebox.showinfo("Başarılı", f"{eski_isim} - {eski_yazar} başarıyla düzenlendi!")
        else:
            messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun.")
    else:
        messagebox.showwarning("Hata", "Lütfen düzenlemek istediğiniz kitabı seçin.")

# Tkinter ana penceresi
pencere = tk.Tk()
pencere.title("Kütüphane Uygulaması")
pencere.geometry("600x600")
pencere.configure(bg="#797979")  # Arkaplan rengi (açık mavi)

# Başlık
baslik_label = tk.Label(pencere, text="📚 Kütüphane Uygulaması", font=("Helvetica", 18, "bold"), bg="#797979",fg="#FFFFFF")
baslik_label.pack(pady=10)

# Kitap Ekleme Alanı
frame_kitap_ekle = tk.Frame(pencere, bg="#e1f5fe")
frame_kitap_ekle.pack(pady=10)

# Kitapları yükleme
kutuphane = kitaplari_yukle()

# Kitap listesi alanı
kitap_listesi_label = tk.Label(pencere, text="📖 Kitap Listesi",fg="#FFFFFF", bg="#797979", font=("Arial", 16, "bold"))
kitap_listesi_label.place(x=80, y=200)

kitap_listesi = tk.Listbox(pencere,fg="#797979", font=("Arial", 12,"bold"), width=50, height=8)
kitap_listesi.place(x=80, y=240)

# Kitap ekleme alanı
kitap_adi_label = tk.Label(pencere, text="Kitap Adı:",fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold"))
kitap_adi_label.place(x=80, y=70)

kitap_adi_entry = tk.Entry(pencere, bg="#ffffff",fg="#797979", font=("Arial", 14,), width=30)
kitap_adi_entry.place(x=200, y=70)

yazar_adi_label = tk.Label(pencere, text="Yazar Adı:",fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold"))
yazar_adi_label.place(x=80, y=110)

yazar_adi_entry = tk.Entry(pencere, bg="#ffffff",fg="#797979", font=("Arial", 14), width=30)
yazar_adi_entry.place(x=200, y=110)

kitap_ekle_buton = tk.Button(pencere, text="Kitap Ekle", bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_ekle)
kitap_ekle_buton.place(x=200, y=420)

kitap_sil_buton = tk.Button(pencere, text="Kitap Sil",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_sil)
kitap_sil_buton.place(x=200, y=460)

kitap_duzenle_buton = tk.Button(pencere, text="Kitap Düzenle",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_duzenle)
kitap_duzenle_buton.place(x=200, y=500)

# Listeyi doldurma
for kitap in kutuphane:
    kitap_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")

# Ana döngü
pencere.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
import json

# Dosyadan kitapları okuma
def kitaplari_yukle():
    try:
        with open("kitaplar.json", "r", encoding="utf-8") as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        return []

# Dosyaya kitapları kaydetme
def kitaplari_kaydet():
    with open("kitaplar.json", "w", encoding="utf-8") as f:
        json.dump(kutuphane, f, ensure_ascii=False, indent=4)

# Kitap ekleme fonksiyonu
def kitap_ekle():
    kitap_adi = kitap_adi_entry.get()
    yazar_adi = yazar_adi_entry.get()
    
    if kitap_adi and yazar_adi:
        kutuphane.append({"isim": kitap_adi, "yazar": yazar_adi})
        kitap_listesi.insert(tk.END, f"{kitap_adi} - {yazar_adi}")
        kitap_adi_entry.delete(0, tk.END)
        yazar_adi_entry.delete(0, tk.END)
        kitaplari_kaydet()  # Yeni kitabı dosyaya kaydet
        messagebox.showinfo("Başarılı", "Kitap eklendi!")
    else:
        messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")

# Kitap silme fonksiyonu
def kitap_sil():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        kitap_adi = kitap_listesi.get(secili_kitap)
        kitap_listesi.delete(secili_kitap)
        kutuphane.remove({"isim": kitap_adi.split(" - ")[0], "yazar": kitap_adi.split(" - ")[1]})
        kitaplari_kaydet()  # Kitap silindiğinde dosyayı güncelle
        messagebox.showinfo("Başarılı", f"{kitap_adi} silindi!")
    else:
        messagebox.showwarning("Hata", "Lütfen silmek istediğiniz kitabı seçin.")

# Kitap düzenleme fonksiyonu
def kitap_duzenle():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        eski_kitap = kitap_listesi.get(secili_kitap)
        eski_isim, eski_yazar = eski_kitap.split(" - ")
        
        # Kullanıcıdan yeni bilgiler
        yeni_isim = kitap_adi_entry.get()
        yeni_yazar = yazar_adi_entry.get()
        
        if yeni_isim and yeni_yazar:
            kutuphane.remove({"isim": eski_isim, "yazar": eski_yazar})
            kutuphane.append({"isim": yeni_isim, "yazar": yeni_yazar})
            kitap_listesi.delete(secili_kitap)
            kitap_listesi.insert(secili_kitap, f"{yeni_isim} - {yeni_yazar}")
            kitaplari_kaydet()  # Güncellenen bilgiyi dosyaya kaydet
            messagebox.showinfo("Başarılı", f"{eski_isim} - {eski_yazar} başarıyla düzenlendi!")
        else:
            messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun.")
    else:
        messagebox.showwarning("Hata", "Lütfen düzenlemek istediğiniz kitabı seçin.")
        
# Kitap arama fonksiyonu
def kitap_ara():
    arama_kelimesi = arama_entry.get()
    sonuc_listesi.delete(0, tk.END)
    bulunan_kitaplar = [kitap for kitap in kutuphane if arama_kelimesi.lower() in kitap["isim"].lower() or arama_kelimesi.lower() in kitap["yazar"].lower()]
    
    if bulunan_kitaplar:
        for kitap in bulunan_kitaplar:
            sonuc_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")
    else:
        messagebox.showinfo("Sonuç Yok", "Aradığınız kitap bulunamadı.")

# Tkinter ana penceresi
pencere = tk.Tk()
pencere.title("Kütüphane Uygulaması")
pencere.geometry("1100x600")
pencere.configure(bg="#797979")  # Arkaplan rengi (açık mavi)

# Başlık
baslik_label = tk.Label(pencere, text="📚 Kütüphane Uygulaması", font=("Helvetica", 18, "bold"), bg="#797979",fg="#FFFFFF")
baslik_label.pack(pady=10)

# Kitap Ekleme Alanı
frame_kitap_ekle = tk.Frame(pencere, bg="#e1f5fe")
frame_kitap_ekle.pack(pady=10)

# Kitapları yükleme
kutuphane = kitaplari_yukle()

# Kitap listesi alanı
kitap_listesi_label = tk.Label(pencere, text="📖 Kitap Listesi",fg="#FFFFFF", bg="#797979", font=("Arial", 16, "bold"))
kitap_listesi_label.place(x=80, y=200)

kitap_listesi = tk.Listbox(pencere,fg="#797979", font=("Arial", 12,"bold"), width=50, height=8)
kitap_listesi.place(x=80, y=240)

# Kitap ekleme alanı
kitap_adi_label = tk.Label(pencere, text="Kitap Adı:",fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold"))
kitap_adi_label.place(x=80, y=70)

kitap_adi_entry = tk.Entry(pencere, bg="#ffffff",fg="#797979", font=("Arial", 14,), width=30)
kitap_adi_entry.place(x=200, y=70)

yazar_adi_label = tk.Label(pencere, text="Yazar Adı:",fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold"))
yazar_adi_label.place(x=80, y=110)

yazar_adi_entry = tk.Entry(pencere, bg="#ffffff",fg="#797979", font=("Arial", 14), width=30)
yazar_adi_entry.place(x=200, y=110)

kitap_ekle_buton = tk.Button(pencere, text="Kitap Ekle", bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_ekle)
kitap_ekle_buton.place(x=200, y=420)

kitap_sil_buton = tk.Button(pencere, text="Kitap Sil",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_sil)
kitap_sil_buton.place(x=200, y=460)

kitap_duzenle_buton = tk.Button(pencere, text="Kitap Düzenle",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_duzenle)
kitap_duzenle_buton.place(x=200, y=500)

# Listeyi doldurma
for kitap in kutuphane:
    kitap_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")
    
# Kitap Arama Alanı
frame_arama = tk.Frame(pencere, bg="#797979")
frame_arama.place(x=600,y=60)

arama_label = tk.Label(frame_arama, text="Ara:", bg="#797979", fg="#ffffff", font=("Arial", 14))
arama_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

arama_entry = tk.Entry(frame_arama, font=("Arial", 14), width=30)
arama_entry.grid(row=0, column=1, padx=5, pady=5)

arama_buton = tk.Button(frame_arama, text="Ara", font=("Arial", 12, "bold"), bg="#c0c0c0", fg="#000000", command=kitap_ara)
arama_buton.grid(row=0, column=2, padx=5, pady=5)

# Arama Sonuçları
sonuc_listesi_label = tk.Label(pencere, text="🔍 Arama Sonuçları", bg="#797979", fg="#ffffff", font=("Helvetica", 14, "bold"))
sonuc_listesi_label.place(x=600,y=110)

sonuc_listesi = tk.Listbox(pencere, font=("Arial", 12), width=50, height=4, bg="#ffffff", fg="#000000", selectbackground="#bbdefb")
sonuc_listesi.place(x=600,y=140)

# Scrollbar oluştur
scrollbar = tk.Scrollbar(pencere, orient="vertical", command=sonuc_listesi.yview)
scrollbar.place(x=1045, y=140, height=80)  # Scrollbar yüksekliği Listbox ile aynı olmalı

# Listbox'ı Scrollbar'a bağla
sonuc_listesi.config(yscrollcommand=scrollbar.set)

for i in range(100):
    sonuc_listesi.insert(tk.END, f"Öğe {i+1}")

# Ana döngü
pencere.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
import json

# Dosyadan kitapları okuma
def kitaplari_yukle():
    try:
        with open("kitaplar.json", "r", encoding="utf-8") as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        return []

# Dosyaya kitapları kaydetme
def kitaplari_kaydet():
    with open("kitaplar.json", "w", encoding="utf-8") as f:
        json.dump(kutuphane, f, ensure_ascii=False, indent=4)

# Kitap ekleme fonksiyonu
def kitap_ekle():
    kitap_adi = kitap_adi_entry.get()
    yazar_adi = yazar_adi_entry.get()
    
    if kitap_adi and yazar_adi:
        kutuphane.append({"isim": kitap_adi, "yazar": yazar_adi})
        kitap_listesi.insert(tk.END, f"{kitap_adi} - {yazar_adi}")
        kitap_adi_entry.delete(0, tk.END)
        yazar_adi_entry.delete(0, tk.END)
        kitaplari_kaydet()  # Yeni kitabı dosyaya kaydet
        messagebox.showinfo("Başarılı", "Kitap eklendi!")
    else:
        messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")

# Kitap silme fonksiyonu
def kitap_sil():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        kitap_adi = kitap_listesi.get(secili_kitap)
        kitap_listesi.delete(secili_kitap)
        kutuphane.remove({"isim": kitap_adi.split(" - ")[0], "yazar": kitap_adi.split(" - ")[1]})
        kitaplari_kaydet()  # Kitap silindiğinde dosyayı güncelle
        messagebox.showinfo("Başarılı", f"{kitap_adi} silindi!")
    else:
        messagebox.showwarning("Hata", "Lütfen silmek istediğiniz kitabı seçin.")

# Kitap düzenleme fonksiyonu
def kitap_duzenle():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        eski_kitap = kitap_listesi.get(secili_kitap)
        eski_isim, eski_yazar = eski_kitap.split(" - ")
        
        # Kullanıcıdan yeni bilgiler
        yeni_isim = kitap_adi_entry.get()
        yeni_yazar = yazar_adi_entry.get()
        
        if yeni_isim and yeni_yazar:
            kutuphane.remove({"isim": eski_isim, "yazar": eski_yazar})
            kutuphane.append({"isim": yeni_isim, "yazar": yeni_yazar})
            kitap_listesi.delete(secili_kitap)
            kitap_listesi.insert(secili_kitap, f"{yeni_isim} - {yeni_yazar}")
            kitaplari_kaydet()  # Güncellenen bilgiyi dosyaya kaydet
            messagebox.showinfo("Başarılı", f"{eski_isim} - {eski_yazar} başarıyla düzenlendi!")
        else:
            messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun.")
    else:
        messagebox.showwarning("Hata", "Lütfen düzenlemek istediğiniz kitabı seçin.")
        
# Kitap arama fonksiyonu
def kitap_ara():
    arama_kelimesi = arama_entry.get()
    sonuc_listesi.delete(0, tk.END)
    bulunan_kitaplar = [kitap for kitap in kutuphane if arama_kelimesi.lower() in kitap["isim"].lower() or arama_kelimesi.lower() in kitap["yazar"].lower()]
    
    if bulunan_kitaplar:
        for kitap in bulunan_kitaplar:
            sonuc_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")
    else:
        messagebox.showinfo("Sonuç Yok", "Aradığınız kitap bulunamadı.")

# Tkinter ana penceresi
pencere = tk.Tk()
pencere.title("Kütüphane Uygulaması")
pencere.geometry("1100x600")
pencere.configure(bg="#797979")  # Arkaplan rengi (açık mavi)

# Başlık
baslik_label = tk.Label(pencere, text="📚 Kütüphane Uygulaması", font=("Helvetica", 18, "bold"), bg="#797979",fg="#FFFFFF")
baslik_label.pack(pady=10)

# Kitap Ekleme Alanı
frame_kitap_ekle = tk.Frame(pencere, bg="#e1f5fe")
frame_kitap_ekle.pack(pady=10)

# Kitapları yükleme
kutuphane = kitaplari_yukle()

# Kitap listesi alanı
kitap_listesi_label = tk.Label(pencere, text="📖 Kitap Listesi",fg="#FFFFFF", bg="#797979", font=("Arial", 16, "bold"))
kitap_listesi_label.place(x=80, y=200)

kitap_listesi = tk.Listbox(pencere,fg="#797979", font=("Arial", 12,"bold"), width=50, height=8)
kitap_listesi.place(x=80, y=240)

# Kitap ekleme alanı
kitap_adi_label = tk.Label(pencere, text="Kitap Adı:",fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold"))
kitap_adi_label.place(x=80, y=70)

kitap_adi_entry = tk.Entry(pencere, bg="#ffffff",fg="#797979", font=("Arial", 14,), width=30)
kitap_adi_entry.place(x=200, y=70)

yazar_adi_label = tk.Label(pencere, text="Yazar Adı:",fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold"))
yazar_adi_label.place(x=80, y=110)

yazar_adi_entry = tk.Entry(pencere, bg="#ffffff",fg="#797979", font=("Arial", 14), width=30)
yazar_adi_entry.place(x=200, y=110)

kitap_ekle_buton = tk.Button(pencere, text="Kitap Ekle", bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_ekle)
kitap_ekle_buton.place(x=200, y=420)

kitap_sil_buton = tk.Button(pencere, text="Kitap Sil",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_sil)
kitap_sil_buton.place(x=200, y=460)

kitap_duzenle_buton = tk.Button(pencere, text="Kitap Düzenle",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_duzenle)
kitap_duzenle_buton.place(x=200, y=500)

# Listeyi doldurma
for kitap in kutuphane:
    kitap_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")
    
# Kitap Arama Alanı
frame_arama = tk.Frame(pencere, bg="#797979")
frame_arama.place(x=600,y=60)

arama_label = tk.Label(frame_arama, text="Ara:", bg="#797979", fg="#ffffff", font=("Arial", 14))
arama_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

arama_entry = tk.Entry(frame_arama, font=("Arial", 14), width=30)
arama_entry.grid(row=0, column=1, padx=5, pady=5)

arama_buton = tk.Button(frame_arama, text="Ara", font=("Arial", 12, "bold"), bg="#c0c0c0", fg="#000000", command=kitap_ara)
arama_buton.grid(row=0, column=2, padx=5, pady=5)

# Arama Sonuçları
sonuc_listesi_label = tk.Label(pencere, text="🔍 Arama Sonuçları", bg="#797979", fg="#ffffff", font=("Helvetica", 14, "bold"))
sonuc_listesi_label.place(x=600,y=110)

sonuc_listesi = tk.Listbox(pencere, font=("Arial", 12), width=50, height=4, bg="#ffffff", fg="#000000", selectbackground="#bbdefb")
sonuc_listesi.place(x=600,y=140)

# Scrollbar oluştur
scrollbar = tk.Scrollbar(pencere, orient="vertical", command=sonuc_listesi.yview)
scrollbar.place(x=1045, y=140, height=80)  # Scrollbar yüksekliği Listbox ile aynı olmalı

# Listbox'ı Scrollbar'a bağla
sonuc_listesi.config(yscrollcommand=scrollbar.set)

for i in range(100):
    sonuc_listesi.insert(tk.END, f"Öğe {i+1}")

# Ana döngü
pencere.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
import json

# Dosyadan kitapları okuma
def kitaplari_yukle():
    try:
        with open("kitaplar.json", "r", encoding="utf-8") as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        return []

# Dosyaya kitapları kaydetme
def kitaplari_kaydet():
    with open("kitaplar.json", "w", encoding="utf-8") as f:
        json.dump(kutuphane, f, ensure_ascii=False, indent=4)

# Kitap ekleme fonksiyonu
def kitap_ekle():
    kitap_adi = kitap_adi_entry.get()
    yazar_adi = yazar_adi_entry.get()
    aciklama = kitap_aciklama_entry.get("1.0", tk.END).strip()
    
    if kitap_adi and yazar_adi:
        kutuphane.append({"isim": kitap_adi, "yazar": yazar_adi, "aciklama": aciklama})
        kitap_listesi.insert(tk.END, f"{kitap_adi} - {yazar_adi}")
        kitap_adi_entry.delete(0, tk.END)
        yazar_adi_entry.delete(0, tk.END)
        kitap_aciklama_entry.delete("1.0", tk.END)
        kitaplari_kaydet()
        messagebox.showinfo("Başarılı", "Kitap eklendi!")
    else:
        messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")

# Kitap detaylarını gösteren pencere
def kitap_aciklama_goster(event):
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        kitap_adi = kitap_listesi.get(secili_kitap)
        kitap_bilgisi = next((k for k in kutuphane if f"{k['isim']} - {k['yazar']}" == kitap_adi), None)
        if kitap_bilgisi:
            detay_pencere = tk.Toplevel(pencere)
            detay_pencere.title("Kitap Detayları")
            detay_pencere.geometry("400x300")

            tk.Label(detay_pencere, text=f"Kitap Adı: {kitap_bilgisi['isim']}", font=("Arial", 12, "bold")).pack(pady=5)
            tk.Label(detay_pencere, text=f"Yazar Adı: {kitap_bilgisi['yazar']}", font=("Arial", 12, "bold")).pack(pady=5)
            tk.Label(detay_pencere, text="Açıklama:", font=("Arial", 12, "bold")).pack(pady=5)

            aciklama_text = tk.Text(detay_pencere, height=10, width=40, wrap=tk.WORD)
            aciklama_text.insert(tk.END, kitap_bilgisi.get("aciklama", "Açıklama yok."))
            aciklama_text.config(state="disabled")  # Sadece görüntüleme için
            aciklama_text.pack()

# Tkinter ana penceresi
pencere = tk.Tk()
pencere.title("Kütüphane Uygulaması")
pencere.geometry("1100x600")
pencere.configure(bg="#797979")

# Başlık
baslik_label = tk.Label(pencere, text="📚 Kütüphane Uygulaması", font=("Helvetica", 18, "bold"), bg="#797979", fg="#FFFFFF")
baslik_label.pack(pady=10)

# Kitapları yükleme
kutuphane = kitaplari_yukle()

# Kitap listesi
kitap_listesi_label = tk.Label(pencere, text="📖 Kitap Listesi", fg="#FFFFFF", bg="#797979", font=("Arial", 16, "bold"))
kitap_listesi_label.place(x=80, y=200)

kitap_listesi = tk.Listbox(pencere, fg="#797979", font=("Arial", 12, "bold"), width=50, height=8)
kitap_listesi.place(x=80, y=240)
kitap_listesi.bind("<Double-1>", kitap_aciklama_goster)  # Çift tıklama ile detay göster

# Kitap ekleme alanı
kitap_adi_label = tk.Label(pencere, text="Kitap Adı:", fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold"))
kitap_adi_label.place(x=80, y=70)

kitap_adi_entry = tk.Entry(pencere, bg="#ffffff", fg="#797979", font=("Arial", 14), width=30)
kitap_adi_entry.place(x=200, y=70)

yazar_adi_label = tk.Label(pencere, text="Yazar Adı:", fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold"))
yazar_adi_label.place(x=80, y=110)

yazar_adi_entry = tk.Entry(pencere, bg="#ffffff", fg="#797979", font=("Arial", 14), width=30)
yazar_adi_entry.place(x=200, y=110)

kitap_aciklama_label = tk.Label(pencere, text="Açıklama:", fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold"))
kitap_aciklama_label.place(x=80, y=150)

kitap_aciklama_entry = tk.Text(pencere, bg="#ffffff", fg="#797979", font=("Arial", 12), width=30, height=4)
kitap_aciklama_entry.place(x=200, y=150)

kitap_ekle_buton = tk.Button(pencere, text="Kitap Ekle", bg="#c0c0c0", width=15, font=("Arial", 12, "bold"), command=kitap_ekle)
kitap_ekle_buton.place(x=200, y=220)

# Listeyi doldurma
for kitap in kutuphane:
    kitap_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")

# Ana döngü
pencere.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
import json

# Dosyadan kitapları okuma
def kitaplari_yukle():
    try:
        with open("kitaplar.json", "r", encoding="utf-8") as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        return []

# Dosyaya kitapları kaydetme
def kitaplari_kaydet():
    with open("kitaplar.json", "w", encoding="utf-8") as f:
        json.dump(kutuphane, f, ensure_ascii=False, indent=4)

# Kitap ekleme fonksiyonu
def kitap_ekle():
    kitap_adi = kitap_adi_entry.get()
    yazar_adi = yazar_adi_entry.get()
    aciklama = kitap_aciklama_entry.get("1.0", tk.END).strip()
    
    if kitap_adi and yazar_adi:
        kutuphane.append({"isim": kitap_adi, "yazar": yazar_adi, "aciklama": aciklama})
        kitap_listesi.insert(tk.END, f"{kitap_adi} - {yazar_adi}")
        kitap_adi_entry.delete(0, tk.END)
        yazar_adi_entry.delete(0, tk.END)
        kitap_aciklama_entry.delete("1.0", tk.END)
        kitaplari_kaydet()
        messagebox.showinfo("Başarılı", "Kitap eklendi!")
    else:
        messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")

# Kitap silme fonksiyonu
def kitap_sil():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        kitap_adi = kitap_listesi.get(secili_kitap)
        kitap_listesi.delete(secili_kitap)
        kutuphane[:] = [k for k in kutuphane if f"{k['isim']} - {k['yazar']}" != kitap_adi]
        kitaplari_kaydet()
        messagebox.showinfo("Başarılı", f"{kitap_adi} silindi!")
    else:
        messagebox.showwarning("Hata", "Lütfen silmek istediğiniz kitabı seçin.")

# Kitap düzenleme fonksiyonu
def kitap_duzenle():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        eski_kitap = kitap_listesi.get(secili_kitap)
        eski_isim, eski_yazar = eski_kitap.split(" - ")
        yeni_isim = kitap_adi_entry.get()
        yeni_yazar = yazar_adi_entry.get()
        yeni_aciklama = kitap_aciklama_entry.get("1.0", tk.END).strip()
        
        if yeni_isim and yeni_yazar:
            for kitap in kutuphane:
                if kitap["isim"] == eski_isim and kitap["yazar"] == eski_yazar:
                    kitap["isim"] = yeni_isim
                    kitap["yazar"] = yeni_yazar
                    kitap["aciklama"] = yeni_aciklama
            kitap_listesi.delete(secili_kitap)
            kitap_listesi.insert(secili_kitap, f"{yeni_isim} - {yeni_yazar}")
            kitaplari_kaydet()
            messagebox.showinfo("Başarılı", "Kitap düzenlendi!")
        else:
            messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")
    else:
        messagebox.showwarning("Hata", "Lütfen düzenlemek istediğiniz kitabı seçin!")

# Kitap arama fonksiyonu
def kitap_ara():
    arama_kelimesi = arama_entry.get()
    sonuc_listesi.delete(0, tk.END)
    bulunan_kitaplar = [kitap for kitap in kutuphane if arama_kelimesi.lower() in kitap["isim"].lower() or arama_kelimesi.lower() in kitap["yazar"].lower()]
    if bulunan_kitaplar:
        for kitap in bulunan_kitaplar:
            sonuc_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")
    else:
        messagebox.showinfo("Sonuç Yok", "Aradığınız kitap bulunamadı.")

# Kitap detaylarını gösteren pencere
def kitap_detay_goster(event):
    secili_kitap = sonuc_listesi.curselection()
    if secili_kitap:
        kitap_adi = sonuc_listesi.get(secili_kitap)
        kitap_bilgisi = next((k for k in kutuphane if f"{k['isim']} - {k['yazar']}" == kitap_adi), None)
        if kitap_bilgisi:
            detay_pencere = tk.Toplevel(pencere)
            detay_pencere.title("Kitap Detayları")
            detay_pencere.geometry("400x300")
            
            tk.Label(detay_pencere, text=f"Kitap Adı: {kitap_bilgisi['isim']}", font=("Arial", 12, "bold")).pack(pady=5)
            tk.Label(detay_pencere, text=f"Yazar: {kitap_bilgisi['yazar']}", font=("Arial", 12, "bold")).pack(pady=5)
            tk.Label(detay_pencere, text="Açıklama:", font=("Arial", 12, "bold")).pack(pady=5)
            
            aciklama_text = tk.Text(detay_pencere, height=10, width=40, wrap=tk.WORD)
            aciklama_text.insert(tk.END, kitap_bilgisi.get("aciklama", "Açıklama yok."))
            aciklama_text.config(state="disabled")
            aciklama_text.pack()

# Tkinter ana penceresi
pencere = tk.Tk()
pencere.title("Kütüphane Uygulaması")
pencere.geometry("1100x650")
pencere.configure(bg="#797979")

# Başlık
tk.Label(pencere, text="📚 Kütüphane Uygulaması", font=("Helvetica", 18, "bold"), bg="#797979", fg="#FFFFFF").pack(pady=10)

# Kitapları yükleme
kutuphane = kitaplari_yukle()

# Kitap listesi
tk.Label(pencere, text="📖 Kitap Listesi", fg="#FFFFFF", bg="#797979", font=("Arial", 16, "bold")).place(x=80, y=260)
kitap_listesi = tk.Listbox(pencere, font=("Arial", 12), width=50, height=8)
kitap_listesi.place(x=80, y=290)
kitap_listesi.bind("<Double-1>", kitap_detay_goster)

# Kitap ekleme alanı
tk.Label(pencere, text="Kitap Adı:", fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold")).place(x=80, y=70)
kitap_adi_entry = tk.Entry(pencere, font=("Arial", 14), width=30)
kitap_adi_entry.place(x=200, y=70)

tk.Label(pencere, text="Yazar Adı:", fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold")).place(x=80, y=110)
yazar_adi_entry = tk.Entry(pencere, font=("Arial", 14), width=30)
yazar_adi_entry.place(x=200, y=110)

tk.Label(pencere, text="Özet:", fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold")).place(x=80, y=150)
kitap_aciklama_entry = tk.Text(pencere, font=("Arial", 14), width=30, height=4)
kitap_aciklama_entry.place(x=200, y=150)

# Butonlar
kitap_ekle_buton = tk.Button(pencere, text="Kitap Ekle", bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_ekle)
kitap_ekle_buton.place(x=200, y=460)
kitap_sil_buton = tk.Button(pencere, text="Kitap Sil",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_sil)
kitap_sil_buton.place(x=200, y=500)
kitap_duzenle_buton = tk.Button(pencere, text="Kitap Düzenle",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_duzenle)
kitap_duzenle_buton.place(x=200, y=540)

# Kitap Arama Alanı
frame_arama = tk.Frame(pencere, bg="#797979")
frame_arama.place(x=600,y=60)

arama_label = tk.Label(frame_arama, text="Ara:", bg="#797979", fg="#ffffff", font=("Arial", 14))
arama_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

arama_entry = tk.Entry(frame_arama, font=("Arial", 14), width=30)
arama_entry.grid(row=0, column=1, padx=5, pady=5)

arama_buton = tk.Button(frame_arama, text="Ara", font=("Arial", 12, "bold"), bg="#c0c0c0", fg="#000000", command=kitap_ara)
arama_buton.grid(row=0, column=2, padx=5, pady=5)

# Arama Sonuçları
sonuc_listesi_label = tk.Label(pencere, text="🔍 Arama Sonuçları", bg="#797979", fg="#ffffff", font=("Helvetica", 14, "bold"))
sonuc_listesi_label.place(x=600,y=110)

sonuc_listesi = tk.Listbox(pencere, font=("Arial", 12), width=50, height=4, bg="#ffffff", fg="#000000", selectbackground="#bbdefb")
sonuc_listesi.place(x=600,y=140)
sonuc_listesi.bind("<Double-1>", kitap_detay_goster)


# Scrollbar oluştur
scrollbar = tk.Scrollbar(pencere, orient="vertical", command=sonuc_listesi.yview)
scrollbar.place(x=1045, y=140, height=80)  # Scrollbar yüksekliği Listbox ile aynı olmalı

# Listbox'ı Scrollbar'a bağla
sonuc_listesi.config(yscrollcommand=scrollbar.set)

for i in range(100):
    sonuc_listesi.insert(tk.END)

# Listeyi doldurma
for kitap in kutuphane:
    kitap_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")

# Ana döngü
pencere.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
import json

# Dosyadan kitapları okuma
def kitaplari_yukle():
    try:
        with open("kitaplar.json", "r", encoding="utf-8") as f:
            return json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        return []

# Dosyaya kitapları kaydetme
def kitaplari_kaydet():
    with open("kitaplar.json", "w", encoding="utf-8") as f:
        json.dump(kutuphane, f, ensure_ascii=False, indent=4)

# Kitap ekleme fonksiyonu
def kitap_ekle():
    kitap_adi = kitap_adi_entry.get()
    yazar_adi = yazar_adi_entry.get()
    aciklama = kitap_aciklama_entry.get("1.0", tk.END).strip()
    
    if kitap_adi and yazar_adi:
        kutuphane.append({"isim": kitap_adi, "yazar": yazar_adi, "aciklama": aciklama})
        kitap_listesi.insert(tk.END, f"{kitap_adi} - {yazar_adi}")
        kitap_adi_entry.delete(0, tk.END)
        yazar_adi_entry.delete(0, tk.END)
        kitap_aciklama_entry.delete("1.0", tk.END)
        kitaplari_kaydet()
        messagebox.showinfo("Başarılı", "Kitap eklendi!")
    else:
        messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")

# Kitap silme fonksiyonu
def kitap_sil():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        kitap_adi = kitap_listesi.get(secili_kitap)
        kitap_listesi.delete(secili_kitap)
        kutuphane[:] = [k for k in kutuphane if f"{k['isim']} - {k['yazar']}" != kitap_adi]
        kitaplari_kaydet()
        messagebox.showinfo("Başarılı", f"{kitap_adi} silindi!")
    else:
        messagebox.showwarning("Hata", "Lütfen silmek istediğiniz kitabı seçin.")

# Kitap düzenleme fonksiyonu
def kitap_duzenle():
    secili_kitap = kitap_listesi.curselection()
    if secili_kitap:
        eski_kitap = kitap_listesi.get(secili_kitap)
        eski_isim, eski_yazar = eski_kitap.split(" - ")
        yeni_isim = kitap_adi_entry.get()
        yeni_yazar = yazar_adi_entry.get()
        yeni_aciklama = kitap_aciklama_entry.get("1.0", tk.END).strip()
        
        if yeni_isim and yeni_yazar:
            for kitap in kutuphane:
                if kitap["isim"] == eski_isim and kitap["yazar"] == eski_yazar:
                    kitap["isim"] = yeni_isim
                    kitap["yazar"] = yeni_yazar
                    kitap["aciklama"] = yeni_aciklama
            kitap_listesi.delete(secili_kitap)
            kitap_listesi.insert(secili_kitap, f"{yeni_isim} - {yeni_yazar}")
            kitaplari_kaydet()
            messagebox.showinfo("Başarılı", "Kitap düzenlendi!")
        else:
            messagebox.showwarning("Hata", "Lütfen tüm alanları doldurun!")
    else:
        messagebox.showwarning("Hata", "Lütfen düzenlemek istediğiniz kitabı seçin!")

# Kitap arama fonksiyonu
def kitap_ara():
    arama_kelimesi = arama_entry.get()
    sonuc_listesi.delete(0, tk.END)
    bulunan_kitaplar = [kitap for kitap in kutuphane if arama_kelimesi.lower() in kitap["isim"].lower() or arama_kelimesi.lower() in kitap["yazar"].lower()]
    if bulunan_kitaplar:
        for kitap in bulunan_kitaplar:
            sonuc_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")
    else:
        messagebox.showinfo("Sonuç Yok", "Aradığınız kitap bulunamadı.")

# Kitap detaylarını gösteren pencere
def kitap_detay_goster(event):
    kaynak = event.widget  # Olayın hangi widget'ta gerçekleştiğini al
    secili_kitap = kaynak.curselection()  # Seçili öğeyi al
    if secili_kitap:
        kitap_adi = kaynak.get(secili_kitap)  # Listeden seçilen öğeyi al
        kitap_bilgisi = next((k for k in kutuphane if f"{k['isim']} - {k['yazar']}" == kitap_adi), None)
        if kitap_bilgisi:
            detay_pencere = tk.Toplevel(pencere)
            detay_pencere.title("Kitap Detayları")
            detay_pencere.geometry("400x300")
            
            tk.Label(detay_pencere, text=f"Kitap Adı: {kitap_bilgisi['isim']}", font=("Arial", 12, "bold")).pack(pady=5)
            tk.Label(detay_pencere, text=f"Yazar: {kitap_bilgisi['yazar']}", font=("Arial", 12, "bold")).pack(pady=5)
            tk.Label(detay_pencere, text="Açıklama:", font=("Arial", 12, "bold")).pack(pady=5)
            
            aciklama_text = tk.Text(detay_pencere, height=10, width=40, wrap=tk.WORD)
            aciklama_text.insert(tk.END, kitap_bilgisi.get("aciklama", "Açıklama yok."))
            aciklama_text.config(state="disabled")
            aciklama_text.pack()

# Tkinter ana penceresi
pencere = tk.Tk()
pencere.title("Kütüphane Uygulaması")
pencere.geometry("1100x650")
pencere.configure(bg="#797979")

# Başlık
tk.Label(pencere, text="📚 Kütüphane Uygulaması", font=("Helvetica", 18, "bold"), bg="#797979", fg="#FFFFFF").pack(pady=10)

# Kitapları yükleme
kutuphane = kitaplari_yukle()

# Kitap listesi
tk.Label(pencere, text="📖 Kitap Listesi", fg="#FFFFFF", bg="#797979", font=("Arial", 16, "bold")).place(x=80, y=260)
kitap_listesi = tk.Listbox(pencere, font=("Arial", 12), width=50, height=8)
kitap_listesi.place(x=80, y=290)
kitap_listesi.bind("<Double-1>", kitap_detay_goster)

# Kitap ekleme alanı
tk.Label(pencere, text="Kitap Adı:", fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold")).place(x=80, y=70)
kitap_adi_entry = tk.Entry(pencere, font=("Arial", 14), width=30)
kitap_adi_entry.place(x=200, y=70)

tk.Label(pencere, text="Yazar Adı:", fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold")).place(x=80, y=110)
yazar_adi_entry = tk.Entry(pencere, font=("Arial", 14), width=30)
yazar_adi_entry.place(x=200, y=110)

tk.Label(pencere, text="Özet:", fg="#FFFFFF", bg="#797979", font=("Arial", 14, "bold")).place(x=80, y=150)
kitap_aciklama_entry = tk.Text(pencere, font=("Arial", 14), width=30, height=4)
kitap_aciklama_entry.place(x=200, y=150)

# Butonlar
kitap_ekle_buton = tk.Button(pencere, text="Kitap Ekle", bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_ekle)
kitap_ekle_buton.place(x=200, y=460)
kitap_sil_buton = tk.Button(pencere, text="Kitap Sil",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_sil)
kitap_sil_buton.place(x=200, y=500)
kitap_duzenle_buton = tk.Button(pencere, text="Kitap Düzenle",bg="#c0c0c0", width =15 , font=("Arial", 12, "bold"), command=kitap_duzenle)
kitap_duzenle_buton.place(x=200, y=540)

# Kitap Arama Alanı
frame_arama = tk.Frame(pencere, bg="#797979")
frame_arama.place(x=600,y=60)

arama_label = tk.Label(frame_arama, text="Ara:", bg="#797979", fg="#ffffff", font=("Arial", 14))
arama_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")

arama_entry = tk.Entry(frame_arama, font=("Arial", 14), width=30)
arama_entry.grid(row=0, column=1, padx=5, pady=5)

arama_buton = tk.Button(frame_arama, text="Ara", font=("Arial", 12, "bold"), bg="#c0c0c0", fg="#000000", command=kitap_ara)
arama_buton.grid(row=0, column=2, padx=5, pady=5)

# Arama Sonuçları
sonuc_listesi_label = tk.Label(pencere, text="🔍 Arama Sonuçları", bg="#797979", fg="#ffffff", font=("Helvetica", 14, "bold"))
sonuc_listesi_label.place(x=600,y=110)

sonuc_listesi = tk.Listbox(pencere, font=("Arial", 12), width=50, height=4, bg="#ffffff", fg="#000000", selectbackground="#bbdefb")
sonuc_listesi.place(x=600,y=140)
sonuc_listesi.bind("<Double-1>", kitap_detay_goster)


# Scrollbar oluştur
scrollbar = tk.Scrollbar(pencere, orient="vertical", command=sonuc_listesi.yview)
scrollbar.place(x=1045, y=140, height=80)  # Scrollbar yüksekliği Listbox ile aynı olmalı

# Listbox'ı Scrollbar'a bağla
sonuc_listesi.config(yscrollcommand=scrollbar.set)

for i in range(100):
    sonuc_listesi.insert(tk.END)

# Listeyi doldurma
for kitap in kutuphane:
    kitap_listesi.insert(tk.END, f"{kitap['isim']} - {kitap['yazar']}")

# Ana döngü
pencere.mainloop()
